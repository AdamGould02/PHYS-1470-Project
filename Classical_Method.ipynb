# %%
import numpy
import time

#This checks if the expression is true, prints out the variables and whether or not the it passed
def check(x, y, z):
    expression= (x)
    if(expression):print(x," ",y," ",z, "\n     PASSED\n")
    else:print(x," ",y," ",z, "\n    Failed\n")

    return expression;

#This part is setting up variables
print("X      Y       Z")

x=True
y=True
z=True


i=0;
j=0;
k=0;
casespassed=0;

start_time = time.time()

# This code goes through all possible combinations of x, y, and z to check which ones pass
for x in range(2):
  if(x):x=False
  else:x=True
  for y in range(2):
    if(y):y=False
    else:y=True
    for z in range(2):
      if(z):z=False
      else:z=True
      if(check(x,y,z)):
        casespassed+=1
end_time=time.time()

#This is to check if no cases pass
if(casespassed==0):
  print("No Cases Passed")
print("CASSES PASSED: ", casespassed)

totaltime=end_time-start_time
# Out:
# X      Y       Z
# True   True   True
#      PASSED
#
# True   True   False
#      PASSED
#
# True   False   True
#      PASSED
#
# True   False   False
#      PASSED
#
# False   True   True
#     Failed
#
# False   True   False
#     Failed
#
# False   False   True
#     Failed
#
# False   False   False
#     Failed
#
# CASSES PASSED:  4

# %%
import numpy
import time

#This checks if the expression is true, prints out the variables and whether or not the it passed
def check(x, y, z):
    expression= (((x==y)==(z))&(x))
    if(expression):print(x," ",y," ",z, "\n     PASSED\n")
    else:print(x," ",y," ",z, "\n    Failed\n")

    return expression;

#This part is setting up variables
print("X      Y       Z")

x=True
y=True
z=True


i=0;
j=0;
k=0;
casespassed=0;

start_time = time.time()

# This code goes through all possible combinations of x, y, and z to check which ones pass
for x in range(2):
  if(x):x=False
  else:x=True
  for y in range(2):
    if(y):y=False
    else:y=True
    for z in range(2):
      if(z):z=False
      else:z=True
      if(check(x,y,z)):
        casespassed+=1
end_time=time.time()

#This is to check if no cases pass
if(casespassed==0):
  print("No Cases Passed")
print("CASSES PASSED: ", casespassed)

totaltime=end_time-start_time
# Out:
# X      Y       Z
# True   True   True
#      PASSED
#
# True   True   False
#     Failed
#
# True   False   True
#     Failed
#
# True   False   False
#      PASSED
#
# False   True   True
#     Failed
#
# False   True   False
#     Failed
#
# False   False   True
#     Failed
#
# False   False   False
#     Failed
#
# CASSES PASSED:  2

# %%
import numpy
import time

#This checks if the expression is true, prints out the variables and whether or not the it passed
def check(x, y, z):
    expression= ((((x==y)==(z))&(x))&((y==(x|z))!=x))
    if(expression):print(x," ",y," ",z, "\n     PASSED\n")
    else:print(x," ",y," ",z, "\n    Failed\n")

    return expression;

#This part is setting up variables
print("X      Y       Z")

x=True
y=True
z=True


i=0;
j=0;
k=0;
casespassed=0;

start_time = time.time()

# This code goes through all possible combinations of x, y, and z to check which ones pass
for x in range(2):
  if(x):x=False
  else:x=True
  for y in range(2):
    if(y):y=False
    else:y=True
    for z in range(2):
      if(z):z=False
      else:z=True
      if(check(x,y,z)):
        casespassed+=1
end_time=time.time()

#This is to check if no cases pass
if(casespassed==0):
  print("No Cases Passed")
print("CASSES PASSED: ", casespassed)

totaltime=end_time-start_time
# Out:
# X      Y       Z
# True   True   True
#     Failed
#
# True   True   False
#     Failed
#
# True   False   True
#     Failed
#
# True   False   False
#      PASSED
#
# False   True   True
#     Failed
#
# False   True   False
#     Failed
#
# False   False   True
#     Failed
#
# False   False   False
#     Failed
#
# CASSES PASSED:  1
